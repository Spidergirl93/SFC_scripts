# %%
import pandas as pd
import matplotlib.pyplot as plt
import morton

# %%
df = pd.read_csv ('../Data/Ausschnitte/Hard_Braking/braking_cut_8_brakes.csv', sep=';', usecols = ['sampleTimeStamp.seconds','sampleTimeStamp.microseconds','lat', 'lon', 'speed', 'accel_lon', 'accel_trans', 'accel_down'])


#df = pd.read_csv ('../Data/database_rec_test_csv/opendlv.device.gps.pos.Grp1Data-0.csv', sep=';', usecols = ['sampleTimeStamp.seconds','sampleTimeStamp.microseconds','lat', 'lon', 'speed', 'accel_lon', 'accel_trans', 'accel_down'])
#df.rename(columns = {'timestamp:10881:<lon>':'ts', 'accel_lon:10881:<double>':'accel_lon', 'accel_trans:10881:<double>':'accel_trans', 'accel_down:10881:<double>':'accel_down'}, inplace = True)

# %%
df['ts'] = (df['sampleTimeStamp.seconds']*1000000)+df['sampleTimeStamp.microseconds']
df = df.drop(columns=['sampleTimeStamp.seconds', 'sampleTimeStamp.microseconds'])

# %%
df
# Out:
#             lat        lon     speed  accel_lon  accel_trans  accel_down  \
# 0     57.718742  11.958157  3.919986   0.958510     1.773054   -0.070448
# 1     57.718743  11.958154  3.880830   1.153120     1.779929   -0.113446
# 2     57.718744  11.958151  3.842020   1.154697     1.804190   -0.091907
# 3     57.718744  11.958148  3.802006   1.139854     1.707745    0.049844
# 4     57.718745  11.958145  3.761051   1.152900     1.682915    0.044875
# ...         ...        ...       ...        ...          ...         ...
# 4394  57.718744  11.958597  2.942660  -0.109660    -1.716671    0.125163
# 4395  57.718742  11.958598  2.974508  -0.200638    -1.606261   -0.168215
# 4396  57.718741  11.958598  3.004279  -0.054665    -1.799528    0.009359
# 4397  57.718740  11.958599  3.032090  -0.036978    -1.956327    0.030983
# 4398  57.718739  11.958599  3.058596  -0.136479    -1.980069   -0.095787
#
#                     ts
# 0     1646666550045396
# 1     1646666550095404
# 2     1646666550145481
# 3     1646666550195461
# 4     1646666550245397
# ...                ...
# 4394  1646666769752738
# 4395  1646666769802735
# 4396  1646666769852804
# 4397  1646666769902834
# 4398  1646666769952825
#
# [4399 rows x 7 columns]

# %%
#faktor_multiply = 1000000; offset = 10

#df['lon'] = df.apply(lambda x: int(x['lon']*faktor_multiply) , axis=1)
#df['lat'] = df.apply(lambda x: int(x['lat']*faktor_multiply) , axis=1)

#df.plot(x = 'lon', y = 'lat')
# Out:
# <AxesSubplot:xlabel='lon'>

# %%
df
# Out:
#            lat       lon     speed  accel_lon  accel_trans  accel_down  \
# 0     57718742  11958157  3.919986   0.958510     1.773054   -0.070448
# 1     57718743  11958154  3.880830   1.153120     1.779929   -0.113446
# 2     57718743  11958151  3.842020   1.154697     1.804190   -0.091907
# 3     57718744  11958147  3.802006   1.139854     1.707745    0.049844
# 4     57718745  11958144  3.761051   1.152900     1.682915    0.044875
# ...        ...       ...       ...        ...          ...         ...
# 4394  57718743  11958597  2.942660  -0.109660    -1.716671    0.125163
# 4395  57718742  11958597  2.974508  -0.200638    -1.606261   -0.168215
# 4396  57718741  11958598  3.004279  -0.054665    -1.799528    0.009359
# 4397  57718739  11958598  3.032090  -0.036978    -1.956327    0.030983
# 4398  57718738  11958599  3.058596  -0.136479    -1.980069   -0.095787
#
#                     ts
# 0     1646666550045396
# 1     1646666550095404
# 2     1646666550145481
# 3     1646666550195461
# 4     1646666550245397
# ...                ...
# 4394  1646666769752738
# 4395  1646666769802735
# 4396  1646666769852804
# 4397  1646666769902834
# 4398  1646666769952825
#
# [4399 rows x 7 columns]

# %%
offset = 10

df['accel_lon'] = df['accel_lon'].add(offset)
df['accel_trans'] = df['accel_trans'].add(offset)
df['accel_down'] = df['accel_down'].add(offset)

faktor_multiply = 10000

df['accel_lon'] = df.apply(lambda x: int(x['accel_lon']*faktor_multiply) , axis=1)
df['accel_trans'] = df.apply(lambda x: int(x['accel_trans']*faktor_multiply) , axis=1)
df['accel_down'] = df.apply(lambda x: int(x['accel_down']*faktor_multiply) , axis=1)

# %%
df
# Out:
#            lat       lon     speed  accel_lon  accel_trans  accel_down  \
# 0     57718742  11958157  3.919986     109585       117730       99295
# 1     57718743  11958154  3.880830     111531       117799       98865
# 2     57718743  11958151  3.842020     111546       118041       99080
# 3     57718744  11958147  3.802006     111398       117077      100498
# 4     57718745  11958144  3.761051     111529       116829      100448
# ...        ...       ...       ...        ...          ...         ...
# 4394  57718743  11958597  2.942660      98903        82833      101251
# 4395  57718742  11958597  2.974508      97993        83937       98317
# 4396  57718741  11958598  3.004279      99453        82004      100093
# 4397  57718739  11958598  3.032090      99630        80436      100309
# 4398  57718738  11958599  3.058596      98635        80199       99042
#
#                     ts
# 0     1646666550045396
# 1     1646666550095404
# 2     1646666550145481
# 3     1646666550195461
# 4     1646666550245397
# ...                ...
# 4394  1646666769752738
# 4395  1646666769802735
# 4396  1646666769852804
# 4397  1646666769902834
# 4398  1646666769952825
#
# [4399 rows x 7 columns]

# %%
m = morton.Morton(dimensions=2, bits=18)

def set_value(row):    
    return m.pack(int(row['accel_lon']), int(row['accel_trans']))


df['morton'] = df.apply(set_value, axis=1)

# %%
dff = df[(df['ts'] > 1646666719952825) & (df['ts'] < 1646666769952825)]
#dff = df[(df['ts'] > 1646666550000000) & (df['ts'] < 1646666570000000)]
# dff = df[(df['ts'] > 1646666563800000) & (df['ts'] < 1646666564800000)]

#dff = df[(df['accel_lon'] > 140000)]
#dff = df[(df['morton'] > 26776019010)]
#dff = df

# %%
dff.plot(x = 'lon', y = 'lat')
# Out:
# <AxesSubplot:xlabel='lon'>

# %%
dff.plot(x = 'ts', y = 'speed')
# Out:
# <AxesSubplot:xlabel='ts'>

# %%
dff.plot(x = 'ts', y=['accel_lon', 'accel_trans'] )
# Out:
# <AxesSubplot:xlabel='ts'>

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

dff.plot(kind='scatter',x='accel_lon',y='accel_trans', color = dff['ts'], ax=ax)
# Out:
# <AxesSubplot:xlabel='accel_lon', ylabel='accel_trans'>

# %%
dff
# Out:
#            lat       lon     speed  accel_lon  accel_trans  accel_down  \
# 3399  57718782  11958487  1.832739      99752       101871      101567
# 3400  57718782  11958488  1.831790     100259       100582       97771
# 3401  57718782  11958490  1.830584      99527       100603       99410
# 3402  57718781  11958491  1.829160      99976        99253       97138
# 3403  57718781  11958493  1.831100      98739        99200       99653
# ...        ...       ...       ...        ...          ...         ...
# 4393  57718744  11958596  2.909300      97399        83118      100965
# 4394  57718743  11958597  2.942660      98903        82833      101251
# 4395  57718742  11958597  2.974508      97993        83937       98317
# 4396  57718741  11958598  3.004279      99453        82004      100093
# 4397  57718739  11958598  3.032090      99630        80436      100309
#
#                     ts       morton
# 3399  1646666720001146  16117918954
# 3400  1646666720051097  16115952685
# 3401  1646666720101091  16115628703
# 3402  1646666720151115  16108145250
# 3403  1646666720201104  16106898693
# ...                ...          ...
# 4393  1646666769702749  13781474749
# 4394  1646666769752738  14496469783
# 4395  1646666769802735  13782415427
# 4396  1646666769852804  14496577393
# 4397  1646666769902834  14136446580
#
# [999 rows x 8 columns]

# %%
#m = morton.Morton(dimensions=2, bits=30)

#dff['accel_lon']

#m.pack(int(dff['accel_lon']), int(dff['accel_trans']))

# %%
dff
# Out:
#            lat       lon     speed  accel_lon  accel_trans  accel_down  \
# 3399  57718782  11958487  1.832739      99752       101871      101567
# 3400  57718782  11958488  1.831790     100259       100582       97771
# 3401  57718782  11958490  1.830584      99527       100603       99410
# 3402  57718781  11958491  1.829160      99976        99253       97138
# 3403  57718781  11958493  1.831100      98739        99200       99653
# ...        ...       ...       ...        ...          ...         ...
# 4393  57718744  11958596  2.909300      97399        83118      100965
# 4394  57718743  11958597  2.942660      98903        82833      101251
# 4395  57718742  11958597  2.974508      97993        83937       98317
# 4396  57718741  11958598  3.004279      99453        82004      100093
# 4397  57718739  11958598  3.032090      99630        80436      100309
#
#                     ts       morton
# 3399  1646666720001146  16117918954
# 3400  1646666720051097  16115952685
# 3401  1646666720101091  16115628703
# 3402  1646666720151115  16108145250
# 3403  1646666720201104  16106898693
# ...                ...          ...
# 4393  1646666769702749  13781474749
# 4394  1646666769752738  14496469783
# 4395  1646666769802735  13782415427
# 4396  1646666769852804  14496577393
# 4397  1646666769902834  14136446580
#
# [999 rows x 8 columns]

# %%
min = dff['morton'].min()
max = dff['morton'].max()
max = 30000000000

print("Diagramm incomming...")

plt.hist(dff['morton'], bins=200)
plt.xlim(0,max)
plt.ylim(0,1)
plt.show()
# Out:
# Diagramm incomming...

# %%
dff.to_csv(r'../Data/Ausschnitte/Hard_Braking/Braking_eine_runde.csv', sep=';', index = False)
