# %%
import pandas as pd
import matplotlib.pyplot as plt
import morton
import base64

# %%
df = pd.read_csv ('../Data/Messfahrten/20220921/CSV/Testgelaende/Testgelaende_noise_LC/opendlv.device.gps.pos.Grp1Data-0.csv', sep=';', usecols = ['sampleTimeStamp.seconds','sampleTimeStamp.microseconds','lat', 'lon', 'speed', 'accel_lon', 'accel_trans', 'accel_down'])
#df.rename(columns = {'timestamp:10881:<lon>':'ts', 'accel_lon:10881:<double>':'accel_lon', 'accel_trans:10881:<double>':'accel_trans', 'accel_down:10881:<double>':'accel_down'}, inplace = True)

df['ts'] = (df['sampleTimeStamp.seconds']*1000000)+df['sampleTimeStamp.microseconds']

# %%
label = pd.read_csv('../Data/Messfahrten/20220921/CSV/Testgelaende/Testgelaende_noise_LC/opendlv.system.LogMessage-999.csv', sep=';', usecols=['sampleTimeStamp.seconds', 'sampleTimeStamp.microseconds','description'])
label['ts'] = (label['sampleTimeStamp.seconds']*1000000)+label['sampleTimeStamp.microseconds']
label['label'] = label['description'].apply(lambda b: str(base64.b64decode(b)))
#label = label[label['label'].str.contains("round") == True]
label = label.drop(columns='description')

# %%
df['ts'][0]
# Out:
# 1663764199902227

# %%
label
# Out:
#     sampleTimeStamp.seconds  sampleTimeStamp.microseconds                ts  \
# 0                1663767399                        363000  1663767399363000
# 1                1663767416                        555000  1663767416555000
# 2                1663767484                        483000  1663767484483000
# 3                1663767501                         77000  1663767501077000
# 4                1663767523                          1000  1663767523001000
# 5                1663767546                        314000  1663767546314000
# 6                1663767556                        546000  1663767556546000
# 7                1663767567                        514000  1663767567514000
# 8                1663767581                        899000  1663767581899000
# 9                1663767613                         49000  1663767613049000
# 10               1663767621                        652000  1663767621652000
# 11               1663767644                        824000  1663767644824000
# 12               1663767654                        336000  1663767654336000
# 13               1663767694                        183000  1663767694183000
# 14               1663767714                        858000  1663767714858000
# 15               1663767725                        654000  1663767725654000
# 16               1663767765                        963000  1663767765963000
# 17               1663767779                        119000  1663767779119000
# 18               1663767797                        246000  1663767797246000
# 19               1663767865                        716000  1663767865716000
# 20               1663767969                        542000  1663767969542000
# 21               1663768024                        732000  1663768024732000
# 22               1663768058                        588000  1663768058588000
# 23               1663768113                        463000  1663768113463000
# 24               1663768140                        434000  1663768140434000
# 25               1663768147                        997000  1663768147997000
# 26               1663768278                        849000  1663768278849000
# 27               1663768327                         83000  1663768327083000
# 28               1663768333                        954000  1663768333954000
# 29               1663768378                        914000  1663768378914000
# 30               1663768387                        591000  1663768387591000
# 31               1663768421                        506000  1663768421506000
# 32               1663768455                         74000  1663768455074000
# 33               1663768488                         69000  1663768488069000
# 34               1663768501                        495000  1663768501495000
# 35               1663768590                        394000  1663768590394000
# 36               1663768601                        946000  1663768601946000
# 37               1663768615                        733000  1663768615733000
# 38               1663768622                        529000  1663768622529000
# 39               1663768701                        720000  1663768701720000
# 40               1663768707                        372000  1663768707372000
# 41               1663768739                        686000  1663768739686000
# 42               1663768766                        760000  1663768766760000
#
#                              label
# 0                         b'brake'
# 1                         b'round'
# 2                    b'lc to left'
# 3                   b'lc to rigth'
# 4                   b'lc to right'
# 5    b'curve to right 90 crossway'
# 6                    b'lc to left'
# 7                    b'lc to left'
# 8                    b'lc to left'
# 9                    b'lc to left'
# 10                  b'lc to right'
# 11                   b'lc to left'
# 12                  b'lc to right'
# 13                b'light s curve'
# 14   b'left curve und lane change'
# 15                 b'lc to right '
# 16                   b'lc to left'
# 17                  b'lc to rigth'
# 18                  b'lc to right'
# 19    b'autobahn auf  bzw abfahrt'
# 20             b'autobahn abfahrt'
# 21               b'curve to right'
# 22                  b'lc to right'
# 23          b'light stuck traffic'
# 24                   b'lc to left'
# 25                  b'traffic jam'
# 26                  b'lc to right'
# 27                  b'lc to rigth'
# 28             b'abfahrt autobahn'
# 29    b'lc to right \\/ einordnen'
# 30                        b'round'
# 31                        b'round'
# 32                      b'round 2'
# 33                b'traffic light'
# 34                        b'round'
# 35                   b'lc to left'
# 36                  b'lc to rigth'
# 37                   b'lc to left'
# 38               b'abfahrt rechts'
# 39  b'waiting vor stuff to finish'
# 40                    b'turn left'
# 41                    b'turn left'
# 42           b'parking side right'

# %%
#faktor_multiply = 1000000; offset = 10

#df['lon_mult'] = df.apply(lambda x: int(x['lon']*faktor_multiply) , axis=1)
#df['lat_mult'] = df.apply(lambda x: int(x['lat']*faktor_multiply) , axis=1)

df.plot(x = 'lon', y = 'lat')
# Out:
# <AxesSubplot:xlabel='lon'>

# %%
df.plot(x = 'ts', y = ['accel_lon', 'accel_trans'])
# Out:
# <AxesSubplot:xlabel='ts'>

# %%
# dff = df[(df['ts'] > 1646666562000000) & (df['ts'] < 1646666566000000)]
# dff = df[(df['ts'] > 1646666550000000) & (df['ts'] < 1646666770000000)]
# dff = df[(df['ts'] > 1663764853002227) & (df['ts'] < 1663765093002227)] # lanechange
# dff = df[(df['ts'] > 1663767219379889) & (df['ts'] < 1663767219379889)] # & (df['ts'] < 1663767254379889)]
# dff = df[(df['ts'] > 1663767093379889) & (df['ts'] < 1663767111159889)]

time_stamp = 1663767714858000
dff = df[(df['ts'] > time_stamp - 9000000) & (df['ts'] < time_stamp + 1500000)]


# dff = df[(df['ts'] > 1663767714858000) & (df['ts'] < 1663767814858000)]

#dff = df[(df['accel_lon'] > 140000)]
#dff = df[(df['morton'] > 26776019010)]
#dff = df

# %%
dff.plot(x = 'lon', y = 'lat')
plt.show()
dff.plot(x = 'ts', y=['accel_lon', 'accel_trans'] )
#for idx, row in label.iterrows():
#    plt.annotate(row['label'], (row['ts'], 2.5), rotation=60)
plt.show()

# %%
dff = dff.drop(columns=['ts'])

# %%
dff.to_csv(r'../Data/Ausschnitte/Hard_Braking/LC_in_Kurve_cut.csv', sep=';', index = False)
